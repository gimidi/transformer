# %%
import pandas as pd

# %%
# !ls
# Out:
# content.csv  correlations.csv  dig_data.ipynb  kaggle  switch  topics.csv

# %%
# !ls switch
# Out:
# README.md      content_3.csv	   topic2string_3.pkl  topics_3.csv
# content_0.csv  topic2string_0.pkl  topics_0.csv
# content_1.csv  topic2string_1.pkl  topics_1.csv
# content_2.csv  topic2string_2.pkl  topics_2.csv

# %%
# !ls kaggle
# Out:
# README.md	content.csv	  sample_submission.csv
# Untitled.ipynb	correlations.csv  topics.csv

# %%
pd.read_csv('kaggle/correlations.csv')
# Out:
#              topic_id                                        content_ids
# 0      t_00004da3a1b2  c_1108dd0c7a5d c_376c5a8eb028 c_5bc0e1e2cba0 c...
# 1      t_00068291e9a4  c_639ea2ef9c95 c_89ce9367be10 c_ac1672cdcd2c c...
# 2      t_00069b63a70a                                     c_11a1dc0bfb99
# 3      t_0006d41a73a8  c_0c6473c3480d c_1c57a1316568 c_5e375cf14c47 c...
# 4      t_0008768bdee6       c_34e1424229b4 c_7d1a964d66d5 c_aab93ee667f4
# ...               ...                                                ...
# 61512  t_fff830472691                      c_61fb63326e5d c_8f224e321c87
# 61513  t_fff9e5407d13  c_026db653a269 c_0fb048a6412c c_20de77522603 c...
# 61514  t_fffbe1d5d43c                      c_46f852a49c08 c_6659207b25d5
# 61515  t_fffe14f1be1e                                     c_cece166bad6a
# 61516  t_fffe811a6da9                                     c_92b8fad372ee
#
# [61517 rows x 2 columns]

# %%
pd.read_csv('kaggle/sample_submission.csv')
# Out:
#          topic_id                                        content_ids
# 0  t_00004da3a1b2  c_1108dd0c7a5d c_376c5a8eb028 c_5bc0e1e2cba0 c...
# 1  t_00068291e9a4  c_639ea2ef9c95 c_89ce9367be10 c_ac1672cdcd2c c...
# 2  t_00069b63a70a                                     c_11a1dc0bfb99
# 3  t_0006d41a73a8  c_0c6473c3480d c_1c57a1316568 c_5e375cf14c47 c...
# 4  t_4054df11a74e                      c_3695c5dc1df6 c_f2d184a98231

# %%
pd.read_csv('switch/content_0.csv')
# Out:
#                     id                                            title  \
# 0       c_00002381196d  Sumar números de varios dígitos: 48,029+233,930
# 1       c_000087304a9e                   Trovare i fattori di un numero
# 2       c_0000ad142ddb                          Sumar curvas de demanda
# 3       c_0000c03adc8d                              Nado de aproximação
# 4       c_00016694ea2a                 geometry-m3-topic-a-overview.pdf
# ...                ...                                              ...
# 154042  c_fffcbdd4de8b                                 2. 12: Diffusion
# 154043  c_fffe15a2d069                     Sommare facendo gruppi da 10
# 154044  c_fffed7b0d13a                           Introdução à subtração
# 154045  c_ffff04ba7ac7                                     SA of a Cone
# 154046  c_ffffe5254266                                         The Jats
#
#                                               description      kind  \
# ...

# %%
pd.read_csv('switch/topics_0.csv')
# Out:
#                    id                                              title  \
# 0      t_00004da3a1b2                         Откриването на резисторите
# 1      t_000095e03056             Unit 3.3 Enlargements and Similarities
# 2      t_00068291e9a4                    Entradas e saídas de uma função
# 3      t_00069b63a70a                                        Transcripts
# 4      t_0006d41a73a8  Графики на експоненциални функции (Алгебра 2 н...
# ...               ...                                                ...
# 76967  t_fffb0bf2801d                             4.3 Graph of functions
# 76968  t_fffbe1d5d43c                   Inscribed shapes problem solving
# 76969  t_fffe14f1be1e                                          Lección 7
# 76970  t_fffe811a6da9  تحديد العلاقة بين الإحداثيّات القطبية والإحداث...
# 76971  t_fffe88835149  Formation of shadows and eclipses (umbra and p...
#
#                                              description channel category  \
# ...

# %%
import pickle
topic2string_0=pickle.load(open('switch/topic2string_0.pkl','rb'))

# %%
cnt=0
for i in topic2string_0:
    cnt+=1
    if cnt>5:
        break
    print(i)
    print(topic2string_0[i])
    print('=======')
# Out:
# t_00004da3a1b2
# Откриването на резисторите # Открития и проекти # Физика # Наука # Khan Academy (български език) # Изследване на материали, които предизвикват намаление в отклонението, когато се свържат последователно с нашия измервателен уред.
# ...
# t_000095e03056
# Unit 3.3 Enlargements and Similarities # Junior High Level 3 # Ghana JHS Curriculum (in progress) #
# ...
# t_00068291e9a4
# Entradas e saídas de uma função # Álgebra: funções # 9º Ano # Matemática por ano (Alinhada à BNCC) # Khan Academy (Português (Brasil)) # Entenda um pouco mais sobre funções.
# ...
# t_00069b63a70a
# Transcripts # Flow Charts: Logical Thinking? # Engineering # MIT Blossoms #
# ...
# t_0006d41a73a8
# Графики на експоненциални функции (Алгебра 2 ниво) # Показателни и логаритмични функции # Алгебра (цялото съдържание) # Математика # Khan Academy (български език) # Научи повече за графиките на сложните показателни функции от вида y=a*b^(x+c)+d.
# ...

# %%
pd.read_csv('content.csv')
# Out:
#                     id                                             title  \
# 0       c_00002381196d  Sumar números de varios dígitos: 48,029+233,930
# 1       c_000087304a9e                    Trovare i fattori di un numero
# 2       c_0000ad142ddb                           Sumar curvas de demanda
# 3       c_0000c03adc8d                               Nado de aproximação
# 4       c_00016694ea2a                  geometry-m3-topic-a-overview.pdf
# ...                ...                                               ...
# 154042  c_fffcbdd4de8b                                  2. 12: Diffusion
# 154043  c_fffe15a2d069                      Sommare facendo gruppi da 10
# 154044  c_fffed7b0d13a                            Introdução à subtração
# 154045  c_ffff04ba7ac7                                      SA of a Cone
# 154046  c_ffffe5254266                                          The Jats
#
#                                               description      kind  \
# ...

# %%
pd.read_csv('topics.csv')
# Out:
#                    id                                              title  \
# 0      t_00004da3a1b2                         Откриването на резисторите
# 1      t_000095e03056             Unit 3.3 Enlargements and Similarities
# 2      t_00068291e9a4                    Entradas e saídas de uma função
# 3      t_00069b63a70a                                        Transcripts
# 4      t_0006d41a73a8  Графики на експоненциални функции (Алгебра 2 н...
# ...               ...                                                ...
# 76967  t_fffb0bf2801d                             4.3 Graph of functions
# 76968  t_fffbe1d5d43c                   Inscribed shapes problem solving
# 76969  t_fffe14f1be1e                                          Lección 7
# 76970  t_fffe811a6da9  تحديد العلاقة بين الإحداثيّات القطبية والإحداث...
# 76971  t_fffe88835149  Formation of shadows and eclipses (umbra and p...
#
#                                              description channel category  \
# ...

# %%
pd.read_csv('correlations.csv')
# Out:
#              topic_id                                        content_ids  \
# 0      t_00004da3a1b2  c_1108dd0c7a5d c_376c5a8eb028 c_5bc0e1e2cba0 c...
# 1      t_00068291e9a4  c_639ea2ef9c95 c_89ce9367be10 c_ac1672cdcd2c c...
# 2      t_00069b63a70a                                     c_11a1dc0bfb99
# 3      t_0006d41a73a8  c_0c6473c3480d c_1c57a1316568 c_5e375cf14c47 c...
# 4      t_0008768bdee6       c_34e1424229b4 c_7d1a964d66d5 c_aab93ee667f4
# ...               ...                                                ...
# 61512  t_fff830472691                      c_61fb63326e5d c_8f224e321c87
# 61513  t_fff9e5407d13  c_026db653a269 c_0fb048a6412c c_20de77522603 c...
# 61514  t_fffbe1d5d43c                      c_46f852a49c08 c_6659207b25d5
# 61515  t_fffe14f1be1e                                     c_cece166bad6a
# 61516  t_fffe811a6da9                                     c_92b8fad372ee
#
#       language  level      category          parent  fold
# ...
